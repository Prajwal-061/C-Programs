# %%
import pandas as pd 
import matplotlib.pyplot as plt
demo = pd.read_csv("sort_steps_output.txt", sep='\s+', index_col=0)
print(type(demo))
print(demo)
axs=demo.plot(figsize=(12,4),subplots=True)
plt.show()
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\KIIT0001\AppData\Local\Temp\ipykernel_8168\1614853953.py:3: SyntaxWarning: invalid escape sequence '\s'
#   demo = pd.read_csv("sort_steps_output.txt", sep='\s+', index_col=0)
# <class 'pandas.core.frame.DataFrame'>
#            OuterSteps  InnerSteps
# InputSize
# 100                99        2273
# 200               199       10419
# 300               299       21567

# %%
demo["InnerSteps"].plot()
# Out:
# <Axes: xlabel='InputSize'>

# %%
demo["OuterSteps"].plot()
# Out:
# <Axes: xlabel='InputSize'>
